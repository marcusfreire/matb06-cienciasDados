# %% [markdown]
# # Curiosidades sobre o Python

# %% [markdown]
# ## Introspecção
#
# * É nosso Help

# %%
b = [1,2,3]

# %%
b?

# %%
print?

# %% [markdown]
# ### Exemplo documentação de funções
# * Caso seja uma função ou um método de instância, a docstring, se estiver definida, também será exibida.

# %%
def soma_numeros(a,b):
    """"
    Adiciona 2 números
    
    Return
    -------
    soma_numeros : a valor numérico, b valor numérico
    """
    return a+b

# %%
soma_numeros?

# %% [markdown]
# #### Caso queira identificar o o código-fonte

# %%
soma_numeros??

# %% [markdown]
# ### Install Lib direto do Jupyter Notebook

# %% [markdown]
# ![image.png](attachment:image.png)
